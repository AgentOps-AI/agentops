# %%
# %pip install -e ../..

# %%
# %pip install -U 'crewai[tools]'
# %pip install -U 'crewai[agentops]'
# Out:
# Requirement already satisfied: crewai[tools] in /opt/homebrew/lib/python3.11/site-packages (0.41.1)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (1.4.4)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (8.1.7)
# Requirement already satisfied: crewai-tools<0.5.0,>=0.4.26 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (0.4.26)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.114 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (0.1.118)
# Requirement already satisfied: instructor==1.3.3 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (1.3.3)
# Requirement already satisfied: json-repair<0.26.0,>=0.25.2 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (0.25.3)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (1.1.0)
# Requirement already satisfied: langchain<=0.3,>0.2 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (0.2.10)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (1.35.13)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (1.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (1.23.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (1.23.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (2.8.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (1.0.0)
# Requirement already satisfied: regex<2024.0.0,>=2023.12.25 in /opt/homebrew/lib/python3.11/site-packages (from crewai[tools]) (2023.12.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[tools]) (3.9.3)
# Requirement already satisfied: docstring-parser<0.17,>=0.16 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[tools]) (0.16)
# Requirement already satisfied: jiter<0.5.0,>=0.4.1 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[tools]) (0.4.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[tools]) (2.20.1)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[tools]) (13.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[tools]) (8.2.3)
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[tools]) (0.9.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (4.12.3)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.22 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.4.24)
# Requirement already satisfied: docker<8.0.0,>=7.1.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (7.1.0)
# Requirement already satisfied: docx2txt<0.9,>=0.8 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.8)
# Requirement already satisfied: lancedb<0.6.0,>=0.5.4 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.5.7)
# Requirement already satisfied: pyright<2.0.0,>=1.1.350 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.1.354)
# Requirement already satisfied: pytest<9.0.0,>=8.0.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (8.1.1)
# Requirement already satisfied: pytube<16.0.0,>=15.0.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (15.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (2.31.0)
# Requirement already satisfied: selenium<5.0.0,>=4.18.1 in /opt/homebrew/lib/python3.11/site-packages (from crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (4.18.1)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.13.1)
# Requirement already satisfied: cohere<6.0,>=5.3 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (5.6.1)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.44.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.1.43)
# Requirement already satisfied: langchain-cohere<0.2.0,>=0.1.4 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.1.9)
# Requirement already satisfied: langchain-community<0.3.0,>=0.2.6 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.2.9)
# Requirement already satisfied: langchain-openai<0.2.0,>=0.1.7 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.1.16)
# Requirement already satisfied: mem0ai<0.0.6,>=0.0.5 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.0.5)
# Requirement already satisfied: posthog<4.0.0,>=3.0.2 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (3.5.0)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (4.3.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.7.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.0.28)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain<=0.3,>0.2->crewai[tools]) (6.0.1)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.22 in /opt/homebrew/lib/python3.11/site-packages (from langchain<=0.3,>0.2->crewai[tools]) (0.2.22)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain<=0.3,>0.2->crewai[tools]) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/homebrew/lib/python3.11/site-packages (from langchain<=0.3,>0.2->crewai[tools]) (0.1.85)
# Requirement already satisfied: numpy<2,>=1 in /opt/homebrew/lib/python3.11/site-packages (from langchain<=0.3,>0.2->crewai[tools]) (1.26.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (3.6.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (0.27.0)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[tools]) (4.9.0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai[tools]) (1.2.14)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai[tools]) (6.8.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.23.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (1.23.0)
# Requirement already satisfied: opentelemetry-proto==1.23.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (1.23.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-proto==1.23.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[tools]) (4.25.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.44b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai[tools]) (0.44b0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.4.2->crewai[tools]) (0.6.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai[tools]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai[tools]) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai[tools]) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai[tools]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai[tools]) (1.8.2)
# Requirement already satisfied: Mako in /opt/homebrew/lib/python3.11/site-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.3.2)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.13.3->crewai[tools]) (3.6)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (2.5)
# Requirement already satisfied: build>=1.0.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.0.3)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.110.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.24.0.post1)
# Requirement already satisfied: pulsar-client>=3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.16.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.44b0)
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (7.4.0)
# Requirement already satisfied: importlib-resources in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.65.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (4.1.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (29.0.0)
# Requirement already satisfied: mmh3>=4.0.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (3.9.15)
# Requirement already satisfied: boto3<2.0.0,>=1.34.0 in /opt/homebrew/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.34.145)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /opt/homebrew/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.9.5)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.4.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.9.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /opt/homebrew/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.32.0.20240712)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/homebrew/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api<2.0.0,>=1.22.0->crewai[tools]) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/homebrew/lib/python3.11/site-packages (from docker<8.0.0,>=7.1.0->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (2.2.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.17.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.28.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.23.0)
# Requirement already satisfied: packaging>=14.3 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (23.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.16.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (3.19.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.12.3)
# Requirement already satisfied: shapely<3.0.0dev in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.0.3)
# Requirement already satisfied: cachetools in /opt/homebrew/lib/python3.11/site-packages (from gptcache<0.2.0,>=0.1.43->embedchain<0.2.0,>=0.1.114->crewai[tools]) (5.3.3)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai[tools]) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai[tools]) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai[tools]) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api<2.0.0,>=1.22.0->crewai[tools]) (3.15.0)
# Requirement already satisfied: deprecation in /opt/homebrew/lib/python3.11/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (2.1.0)
# Requirement already satisfied: pylance==0.9.18 in /opt/homebrew/lib/python3.11/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.9.18)
# Requirement already satisfied: ratelimiter~=1.0 in /opt/homebrew/lib/python3.11/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.2.0.post0)
# Requirement already satisfied: retry>=0.9.2 in /opt/homebrew/lib/python3.11/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.9.2)
# Requirement already satisfied: semver>=3.0 in /opt/homebrew/lib/python3.11/site-packages (from lancedb<0.6.0,>=0.5.4->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (3.0.2)
# Requirement already satisfied: pyarrow>=12 in /opt/homebrew/lib/python3.11/site-packages (from pylance==0.9.18->lancedb<0.6.0,>=0.5.4->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (12.0.1)
# Requirement already satisfied: langchain-experimental>=0.0.6 in /opt/homebrew/lib/python3.11/site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.0.62)
# Requirement already satisfied: pandas>=1.4.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.0.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.22->langchain<=0.3,>0.2->crewai[tools]) (1.33)
# Requirement already satisfied: groq<0.10.0,>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.9.0)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in /opt/homebrew/lib/python3.11/site-packages (from mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.10.1)
# Requirement already satisfied: together<2.0.0,>=1.2.1 in /opt/homebrew/lib/python3.11/site-packages (from mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.2.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /opt/homebrew/lib/python3.11/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /opt/homebrew/lib/python3.11/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.8.2)
# Requirement already satisfied: nodeenv>=1.6.0 in /opt/homebrew/lib/python3.11/site-packages (from pyright<2.0.0,>=1.1.350->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.8.0)
# Requirement already satisfied: iniconfig in /opt/homebrew/lib/python3.11/site-packages (from pytest<9.0.0,>=8.0.0->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=1.4 in /opt/homebrew/lib/python3.11/site-packages (from pytest<9.0.0,>=8.0.0->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/lib/python3.11/site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai[tools]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/lib/python3.11/site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai[tools]) (2.18.0)
# Requirement already satisfied: contextlib2>=0.5.5 in /opt/homebrew/lib/python3.11/site-packages (from schema<0.8.0,>=0.7.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (21.6.0)
# Requirement already satisfied: trio~=0.17 in /opt/homebrew/lib/python3.11/site-packages (from selenium<5.0.0,>=4.18.1->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in /opt/homebrew/lib/python3.11/site-packages (from selenium<5.0.0,>=4.18.1->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.11.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.145 in /opt/homebrew/lib/python3.11/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.34.145)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/homebrew/lib/python3.11/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.10.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/homebrew/lib/python3.11/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.10.2)
# Requirement already satisfied: pyproject_hooks in /opt/homebrew/lib/python3.11/site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai[tools]) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.9.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /opt/homebrew/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.36.3)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.62.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.7.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.13.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.22->langchain<=0.3,>0.2->crewai[tools]) (2.4)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.6.1)
# Requirement already satisfied: requests-oauthlib in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.3.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (3.2.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai[tools]) (0.1.2)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.11/site-packages (from nodeenv>=1.6.0->pyright<2.0.0,>=1.1.350->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (69.5.1)
# Requirement already satisfied: coloredlogs in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (23.5.26)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.12)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.44b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.44b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.44b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.44b0)
# Requirement already satisfied: opentelemetry-util-http==0.44b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.44b0)
# Requirement already satisfied: asgiref~=3.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (3.6.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.4.3->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.4.3->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2023.3)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /opt/homebrew/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.62.2)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /opt/homebrew/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.10.1)
# Requirement already satisfied: decorator>=3.4.2 in /opt/homebrew/lib/python3.11/site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.4->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /opt/homebrew/lib/python3.11/site-packages (from retry>=0.9.2->lancedb<0.6.0,>=0.5.4->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.11.0)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.1.3 in /opt/homebrew/lib/python3.11/site-packages (from together<2.0.0,>=1.2.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.2.0)
# Requirement already satisfied: filelock<4.0.0,>=3.13.1 in /opt/homebrew/lib/python3.11/site-packages (from together<2.0.0,>=1.2.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (3.13.3)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /opt/homebrew/lib/python3.11/site-packages (from together<2.0.0,>=1.2.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (10.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/homebrew/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.16.4)
# Requirement already satisfied: sortedcontainers in /opt/homebrew/lib/python3.11/site-packages (from trio~=0.17->selenium<5.0.0,>=4.18.1->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (2.4.0)
# Requirement already satisfied: outcome in /opt/homebrew/lib/python3.11/site-packages (from trio~=0.17->selenium<5.0.0,>=4.18.1->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /opt/homebrew/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium<5.0.0,>=4.18.1->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/homebrew/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium<5.0.0,>=4.18.1->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.7.1)
# Requirement already satisfied: httptools>=0.5.0 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (0.18.1)
# Requirement already satisfied: websockets>=10.4 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (12.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/homebrew/lib/python3.11/site-packages (from Mako->alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (2.1.2)
# Requirement already satisfied: h2<5,>=3 in /opt/homebrew/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (4.1.0)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (2023.6.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[tools]) (0.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai[tools]) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/homebrew/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.22->crewai-tools<0.5.0,>=0.4.26->crewai[tools]) (1.3.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /opt/homebrew/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /opt/homebrew/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[tools]) (4.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: crewai[agentops] in /opt/homebrew/lib/python3.11/site-packages (0.41.1)
# Requirement already satisfied: agentops<0.4.0,>=0.3.0 in /Users/braelynboynton/Developer/agentops/agentops (from crewai[agentops]) (0.3.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (1.4.4)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (8.1.7)
# Requirement already satisfied: embedchain<0.2.0,>=0.1.114 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (0.1.118)
# Requirement already satisfied: instructor==1.3.3 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (1.3.3)
# Requirement already satisfied: json-repair<0.26.0,>=0.25.2 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (0.25.3)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (1.1.0)
# Requirement already satisfied: langchain<=0.3,>0.2 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (0.2.10)
# Requirement already satisfied: openai<2.0.0,>=1.13.3 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (1.35.13)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.22.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (1.23.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (1.23.0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.22.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (1.23.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.2 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (2.8.2)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (1.0.0)
# Requirement already satisfied: regex<2024.0.0,>=2023.12.25 in /opt/homebrew/lib/python3.11/site-packages (from crewai[agentops]) (2023.12.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[agentops]) (3.9.3)
# Requirement already satisfied: docstring-parser<0.17,>=0.16 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[agentops]) (0.16)
# Requirement already satisfied: jiter<0.5.0,>=0.4.1 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[agentops]) (0.4.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[agentops]) (2.20.1)
# Requirement already satisfied: rich<14.0.0,>=13.7.0 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[agentops]) (13.7.1)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[agentops]) (8.2.3)
# Requirement already satisfied: typer<1.0.0,>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from instructor==1.3.3->crewai[agentops]) (0.9.0)
# Requirement already satisfied: requests==2.31.0 in /opt/homebrew/lib/python3.11/site-packages (from agentops<0.4.0,>=0.3.0->crewai[agentops]) (2.31.0)
# Requirement already satisfied: psutil==5.9.8 in /opt/homebrew/lib/python3.11/site-packages (from agentops<0.4.0,>=0.3.0->crewai[agentops]) (5.9.8)
# Requirement already satisfied: packaging==23.2 in /opt/homebrew/lib/python3.11/site-packages (from agentops<0.4.0,>=0.3.0->crewai[agentops]) (23.2)
# Requirement already satisfied: termcolor==2.4.0 in /opt/homebrew/lib/python3.11/site-packages (from agentops<0.4.0,>=0.3.0->crewai[agentops]) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests==2.31.0->agentops<0.4.0,>=0.3.0->crewai[agentops]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests==2.31.0->agentops<0.4.0,>=0.3.0->crewai[agentops]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests==2.31.0->agentops<0.4.0,>=0.3.0->crewai[agentops]) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests==2.31.0->agentops<0.4.0,>=0.3.0->crewai[agentops]) (2024.2.2)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.13.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.2 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (4.12.3)
# Requirement already satisfied: chromadb<0.5.0,>=0.4.24 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.4.24)
# Requirement already satisfied: cohere<6.0,>=5.3 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (5.6.1)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.44.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.1.43)
# Requirement already satisfied: langchain-cohere<0.2.0,>=0.1.4 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.1.9)
# Requirement already satisfied: langchain-community<0.3.0,>=0.2.6 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.2.9)
# Requirement already satisfied: langchain-openai<0.2.0,>=0.1.7 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.1.16)
# Requirement already satisfied: mem0ai<0.0.6,>=0.0.5 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.0.5)
# Requirement already satisfied: posthog<4.0.0,>=3.0.2 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (3.5.0)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (4.3.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.7.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0.27 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.0.28)
# Requirement already satisfied: tiktoken<0.8.0,>=0.7.0 in /opt/homebrew/lib/python3.11/site-packages (from embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain<=0.3,>0.2->crewai[agentops]) (6.0.1)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.22 in /opt/homebrew/lib/python3.11/site-packages (from langchain<=0.3,>0.2->crewai[agentops]) (0.2.22)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain<=0.3,>0.2->crewai[agentops]) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/homebrew/lib/python3.11/site-packages (from langchain<=0.3,>0.2->crewai[agentops]) (0.1.85)
# Requirement already satisfied: numpy<2,>=1 in /opt/homebrew/lib/python3.11/site-packages (from langchain<=0.3,>0.2->crewai[agentops]) (1.26.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[agentops]) (3.6.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[agentops]) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[agentops]) (0.27.0)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[agentops]) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[agentops]) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.13.3->crewai[agentops]) (4.9.0)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai[agentops]) (1.2.14)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-api<2.0.0,>=1.22.0->crewai[agentops]) (6.8.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[agentops]) (1.63.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.23.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[agentops]) (1.23.0)
# Requirement already satisfied: opentelemetry-proto==1.23.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[agentops]) (1.23.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-proto==1.23.0->opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.22.0->crewai[agentops]) (4.25.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.44b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-sdk<2.0.0,>=1.22.0->crewai[agentops]) (0.44b0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.4.2->crewai[agentops]) (0.6.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai[agentops]) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai[agentops]) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai[agentops]) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai[agentops]) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.9.1->instructor==1.3.3->crewai[agentops]) (1.8.2)
# Requirement already satisfied: Mako in /opt/homebrew/lib/python3.11/site-packages (from alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.3.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/lib/python3.11/site-packages (from beautifulsoup4<5.0.0,>=4.12.2->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.5)
# Requirement already satisfied: build>=1.0.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.0.3)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.110.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.24.0.post1)
# Requirement already satisfied: pulsar-client>=3.1.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.16.3)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.23.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /opt/homebrew/lib/python3.11/site-packages (from chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.44b0)
# ...
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.28.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.23.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.16.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (3.19.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.12.3)
# Requirement already satisfied: shapely<3.0.0dev in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.0.3)
# Requirement already satisfied: cachetools in /opt/homebrew/lib/python3.11/site-packages (from gptcache<0.2.0,>=0.1.43->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (5.3.3)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai[agentops]) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.13.3->crewai[agentops]) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/lib/python3.11/site-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api<2.0.0,>=1.22.0->crewai[agentops]) (3.15.0)
# Requirement already satisfied: langchain-experimental>=0.0.6 in /opt/homebrew/lib/python3.11/site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.0.62)
# Requirement already satisfied: pandas>=1.4.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.0.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<0.3.0,>=0.2.22->langchain<=0.3,>0.2->crewai[agentops]) (1.33)
# Requirement already satisfied: groq<0.10.0,>=0.9.0 in /opt/homebrew/lib/python3.11/site-packages (from mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.9.0)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in /opt/homebrew/lib/python3.11/site-packages (from mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.10.1)
# Requirement already satisfied: together<2.0.0,>=1.2.1 in /opt/homebrew/lib/python3.11/site-packages (from mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.2.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /opt/homebrew/lib/python3.11/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /opt/homebrew/lib/python3.11/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.2.1)
# Requirement already satisfied: python-dateutil>2.1 in /opt/homebrew/lib/python3.11/site-packages (from posthog<4.0.0,>=3.0.2->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/lib/python3.11/site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai[agentops]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/lib/python3.11/site-packages (from rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai[agentops]) (2.18.0)
# Requirement already satisfied: contextlib2>=0.5.5 in /opt/homebrew/lib/python3.11/site-packages (from schema<0.8.0,>=0.7.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (21.6.0)
# Requirement already satisfied: botocore<1.35.0,>=1.34.145 in /opt/homebrew/lib/python3.11/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.34.145)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/homebrew/lib/python3.11/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.10.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/homebrew/lib/python3.11/site-packages (from boto3<2.0.0,>=1.34.0->cohere<6.0,>=5.3->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.10.2)
# Requirement already satisfied: pyproject_hooks in /opt/homebrew/lib/python3.11/site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.9.0)
# Requirement already satisfied: starlette<0.37.0,>=0.36.3 in /opt/homebrew/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.36.3)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/homebrew/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.62.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/homebrew/lib/python3.11/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.7.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.13.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.22->langchain<=0.3,>0.2->crewai[agentops]) (2.4)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.6.1)
# Requirement already satisfied: requests-oauthlib in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.3.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /opt/homebrew/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (3.2.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.7.0->instructor==1.3.3->crewai[agentops]) (0.1.2)
# Requirement already satisfied: coloredlogs in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (23.5.26)
# Requirement already satisfied: sympy in /opt/homebrew/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.12)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.44b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.44b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.44b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.44b0)
# Requirement already satisfied: opentelemetry-util-http==0.44b0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.44b0)
# Requirement already satisfied: setuptools>=16.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (69.5.1)
# Requirement already satisfied: asgiref~=3.0 in /opt/homebrew/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.44b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (3.6.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.4.3->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/lib/python3.11/site-packages (from pandas>=1.4.3->langchain-cohere<0.2.0,>=0.1.4->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2023.3)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /opt/homebrew/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.62.2)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /opt/homebrew/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.10.1)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.1.3 in /opt/homebrew/lib/python3.11/site-packages (from together<2.0.0,>=1.2.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.2.0)
# Requirement already satisfied: filelock<4.0.0,>=3.13.1 in /opt/homebrew/lib/python3.11/site-packages (from together<2.0.0,>=1.2.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (3.13.3)
# Requirement already satisfied: pillow<11.0.0,>=10.3.0 in /opt/homebrew/lib/python3.11/site-packages (from together<2.0.0,>=1.2.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (10.4.0)
# Requirement already satisfied: pyarrow>=10.0.1 in /opt/homebrew/lib/python3.11/site-packages (from together<2.0.0,>=1.2.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (12.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /opt/homebrew/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.16.4)
# Requirement already satisfied: httptools>=0.5.0 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.18.1)
# Requirement already satisfied: websockets>=10.4 in /opt/homebrew/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (12.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/homebrew/lib/python3.11/site-packages (from Mako->alembic<2.0.0,>=1.13.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2.1.2)
# Requirement already satisfied: h2<5,>=3 in /opt/homebrew/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (4.1.0)
# Requirement already satisfied: fsspec in /opt/homebrew/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (2023.6.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/homebrew/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (0.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.3.0,>=0.2.6->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/homebrew/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/homebrew/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.24->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (1.3.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /opt/homebrew/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /opt/homebrew/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.0.6,>=0.0.5->embedchain<0.2.0,>=0.1.114->crewai[agentops]) (4.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

os.environ["SERPER_API_KEY"] = "..."
os.environ["OPENAI_API_KEY"] = "..."
os.environ["AGENTOPS_API_KEY"] = "..."

# %%
from crewai import Agent
from crewai_tools.tools import WebsiteSearchTool, SerperDevTool, FileReadTool

web_search_tool = WebsiteSearchTool()
serper_dev_tool = SerperDevTool()
file_read_tool = FileReadTool(
    file_path="job_description_example.md",
    description="A tool to read the job description example file.",
)

class Agents:
    def research_agent(self):
        return Agent(
            role="Research Analyst",
            goal="Analyze the company website and provided description to extract insights on culture, values, and specific needs.",
            tools=[web_search_tool, serper_dev_tool],
            backstory="Expert in analyzing company cultures and identifying key values and needs from various sources, including websites and brief descriptions.",
            verbose=True,
        )

    def writer_agent(self):
        return Agent(
            role="Job Description Writer",
            goal="Use insights from the Research Analyst to create a detailed, engaging, and enticing job posting.",
            tools=[web_search_tool, serper_dev_tool, file_read_tool],
            backstory="Skilled in crafting compelling job descriptions that resonate with the company's values and attract the right candidates.",
            verbose=True,
        )

    def review_agent(self):
        return Agent(
            role="Review and Editing Specialist",
            goal="Review the job posting for clarity, engagement, grammatical accuracy, and alignment with company values and refine it to ensure perfection.",
            tools=[web_search_tool, serper_dev_tool, file_read_tool],
            backstory="A meticulous editor with an eye for detail, ensuring every piece of content is clear, engaging, and grammatically perfect.",
            verbose=True,
        )
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from crewai import Agent
#       2 from crewai_tools.tools import WebsiteSearchTool, SerperDevTool, FileReadTool
#       4 web_search_tool = WebsiteSearchTool()
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/__init__.py:1
# ----> 1 from crewai.agent import Agent
#       2 from crewai.crew import Crew
#       3 from crewai.process import Process
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agent.py:13
#      10 from langchain_openai import ChatOpenAI
#      11 from pydantic import Field, InstanceOf, PrivateAttr, model_validator
# ---> 13 from crewai.agents import CacheHandler, CrewAgentExecutor, CrewAgentParser
#      14 from crewai.agents.agent_builder.base_agent import BaseAgent
#      15 from crewai.memory.contextual.contextual_memory import ContextualMemory
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agents/__init__.py:2
#       1 from .cache.cache_handler import CacheHandler
# ----> 2 from .executor import CrewAgentExecutor
#       3 from .parser import CrewAgentParser
#       4 from .tools_handler import ToolsHandler
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agents/executor.py:14
#      11 from langchain_core.utils.input import get_color_mapping
#      12 from pydantic import InstanceOf
# ---> 14 from crewai.agents.agent_builder.base_agent_executor_mixin import CrewAgentExecutorMixin
#      15 from crewai.agents.tools_handler import ToolsHandler
#      16 from crewai.tools.tool_usage import ToolUsage, ToolUsageErrorException
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/agents/agent_builder/base_agent_executor_mixin.py:4
#       1 import time
#       2 from typing import TYPE_CHECKING, Optional
# ----> 4 from crewai.memory.entity.entity_memory_item import EntityMemoryItem
#       5 from crewai.memory.long_term.long_term_memory_item import LongTermMemoryItem
#       6 from crewai.memory.short_term.short_term_memory_item import ShortTermMemoryItem
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/memory/__init__.py:1
# ----> 1 from .entity.entity_memory import EntityMemory
#       2 from .long_term.long_term_memory import LongTermMemory
#       3 from .short_term.short_term_memory import ShortTermMemory
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/memory/entity/entity_memory.py:3
#       1 from crewai.memory.entity.entity_memory_item import EntityMemoryItem
#       2 from crewai.memory.memory import Memory
# ----> 3 from crewai.memory.storage.rag_storage import RAGStorage
#       6 class EntityMemory(Memory):
#       7     """
#       8     EntityMemory class for managing structured information about entities
#       9     and their relationships using SQLite storage.
#      10     Inherits from the Memory class.
#      11     """
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/memory/storage/rag_storage.py:13
#      10 from embedchain.vectordb.chroma import InvalidDimensionException
#      12 from crewai.memory.storage.interface import Storage
# ---> 13 from crewai.utilities.paths import db_storage_path
#      16 @contextlib.contextmanager
#      17 def suppress_logging(
#      18     logger_name="chromadb.segment.impl.vector.local_persistent_hnsw",
#      19     level=logging.ERROR,
#      20 ):
#      21     logger = logging.getLogger(logger_name)
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/utilities/__init__.py:4
#       2 from .file_handler import FileHandler
#       3 from .i18n import I18N
# ----> 4 from .instructor import Instructor
#       5 from .logger import Logger
#       6 from .parser import YamlParser
#
# File /opt/homebrew/lib/python3.11/site-packages/crewai/utilities/instructor.py:3
#       1 from typing import Any, Optional, Type
# ----> 3 import instructor
#       4 from pydantic import BaseModel, Field, PrivateAttr, model_validator
#       7 class Instructor(BaseModel):
#
# File /opt/homebrew/lib/python3.11/site-packages/instructor/__init__.py:79
#      76     __all__ += ["from_cohere"]
#      78 if importlib.util.find_spec("vertexai") is not None:
# ---> 79     from .client_vertexai import from_vertexai
#      81     __all__ += ["from_vertexai"]
#
# File /opt/homebrew/lib/python3.11/site-packages/instructor/client_vertexai.py:5
#       1 from __future__ import annotations
#       3 from typing import Any
# ----> 5 from vertexai.preview.generative_models import ToolConfig  # type: ignore[reportMissingTypeStubs]
#       6 import vertexai.generative_models as gm  # type: ignore[reportMissingTypeStubs]
#       7 from pydantic import BaseModel
#
# ImportError: cannot import name 'ToolConfig' from 'vertexai.preview.generative_models' (/opt/homebrew/lib/python3.11/site-packages/vertexai/preview/generative_models.py)

# %%
from textwrap import dedent
from crewai import Task

class Tasks:
    def research_company_culture_task(self, agent, company_description, company_domain):
        return Task(
            description=dedent(
                f"""\
								Analyze the provided company website and the hiring manager's company's domain {company_domain}, description: "{company_description}". Focus on understanding the company's culture, values, and mission. Identify unique selling points and specific projects or achievements highlighted on the site.
								Compile a report summarizing these insights, specifically how they can be leveraged in a job posting to attract the right candidates."""
            ),
            expected_output=dedent(
                """\
								A comprehensive report detailing the company's culture, values, and mission, along with specific selling points relevant to the job role. Suggestions on incorporating these insights into the job posting should be included."""
            ),
            agent=agent,
        )

    def research_role_requirements_task(self, agent, hiring_needs):
        return Task(
            description=dedent(
                f"""\
								Based on the hiring manager's needs: "{hiring_needs}", identify the key skills, experiences, and qualities the ideal candidate should possess for the role. Consider the company's current projects, its competitive landscape, and industry trends. Prepare a list of recommended job requirements and qualifications that align with the company's needs and values."""
            ),
            expected_output=dedent(
                """\
								A list of recommended skills, experiences, and qualities for the ideal candidate, aligned with the company's culture, ongoing projects, and the specific role's requirements."""
            ),
            agent=agent,
        )

    def draft_job_posting_task(
        self, agent, company_description, hiring_needs, specific_benefits
    ):
        return Task(
            description=dedent(
                f"""\
								Draft a job posting for the role described by the hiring manager: "{hiring_needs}". Use the insights on "{company_description}" to start with a compelling introduction, followed by a detailed role description, responsibilities, and required skills and qualifications. Ensure the tone aligns with the company's culture and incorporate any unique benefits or opportunities offered by the company.
								Specfic benefits: "{specific_benefits}"""
            ),
            expected_output=dedent(
                """\
								A detailed, engaging job posting that includes an introduction, role description, responsibilities, requirements, and unique company benefits. The tone should resonate with the company's culture and values, aimed at attracting the right candidates."""
            ),
            agent=agent,
        )

    def review_and_edit_job_posting_task(self, agent, hiring_needs):
        return Task(
            description=dedent(
                f"""\
								Review the draft job posting for the role: "{hiring_needs}". Check for clarity, engagement, grammatical accuracy, and alignment with the company's culture and values. Edit and refine the content, ensuring it speaks directly to the desired candidates and accurately reflects the role's unique benefits and opportunities. Provide feedback for any necessary revisions."""
            ),
            expected_output=dedent(
                """\
								A polished, error-free job posting that is clear, engaging, and perfectly aligned with the company's culture and values. Feedback on potential improvements and final approval for publishing. Formated in markdown."""
            ),
            agent=agent,
            output_file="job_posting.md",
        )

    def industry_analysis_task(self, agent, company_domain, company_description):
        return Task(
            description=dedent(
                f"""\
								Conduct an in-depth analysis of the industry related to the company's domain: "{company_domain}". Investigate current trends, challenges, and opportunities within the industry, utilizing market reports, recent developments, and expert opinions. Assess how these factors could impact the role being hired for and the overall attractiveness of the position to potential candidates.
								Consider how the company's position within this industry and its response to these trends could be leveraged to attract top talent. Include in your report how the role contributes to addressing industry challenges or seizing opportunities."""
            ),
            expected_output=dedent(
                """\
								A detailed analysis report that identifies major industry trends, challenges, and opportunities relevant to the company's domain and the specific job role. This report should provide strategic insights on positioning the job role and the company as an attractive choice for potential candidates."""
            ),
            agent=agent,
        )

# %%
from crewai import Crew
import agentops

agentops.init(tags=["crew-job-posting-example"])

tasks = Tasks()
agents = Agents()

company_description = input("What is the company description?\n")
company_domain = input("What is the company domain?\n")
hiring_needs = input("What are the hiring needs?\n")
specific_benefits = input("What are specific_benefits you offer?\n")

# Create Agents
researcher_agent = agents.research_agent()
writer_agent = agents.writer_agent()
review_agent = agents.review_agent()

# Define Tasks for each agent
research_company_culture_task = tasks.research_company_culture_task(
    researcher_agent, company_description, company_domain
)
industry_analysis_task = tasks.industry_analysis_task(
    researcher_agent, company_domain, company_description
)
research_role_requirements_task = tasks.research_role_requirements_task(
    researcher_agent, hiring_needs
)
draft_job_posting_task = tasks.draft_job_posting_task(
    writer_agent, company_description, hiring_needs, specific_benefits
)
review_and_edit_job_posting_task = tasks.review_and_edit_job_posting_task(
    review_agent, hiring_needs
)

# Instantiate the crew with a sequential process
crew = Crew(
    agents=[researcher_agent, writer_agent, review_agent],
    tasks=[
        research_company_culture_task,
        industry_analysis_task,
        research_role_requirements_task,
        draft_job_posting_task,
        review_and_edit_job_posting_task,
    ],
)

# Kick off the process
result = crew.kickoff()

print("Job Posting Creation Process Completed.")
print("Final Job Posting:")
print(result)

agentops.end_session("Success")
